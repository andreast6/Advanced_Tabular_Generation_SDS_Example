# %% [markdown]
# # Lending Club Loan Data Clustering & Seed Instruction Generation
#
# ## 📦 Environment Setup
# - Installs necessary libraries for data analysis

# %%
# !pip install -q hvplot
# Out:
# WARNING: Ignoring invalid distribution -ransformers (/home/cdsw/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/home/cdsw/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/home/cdsw/.local/lib/python3.10/site-packages)

# %% [markdown]
# ## 📊 Data Loading & Preparation
# - Loads dataset from Lending Club loan data CSV
# - Performs train/test split (66%/34%) with random sampling
# - Handles data persistence through pickling for reproducibility

# %%
import hvplot.pandas
import pandas as pd
import numpy as np
SaveSplits=False
df = pd.read_csv("lending_club_loan_two.csv")
data=df.dropna()
import random
import pickle
#train, test,  = train_test_split(data2, test_size=0.33, random_state=42)
random.seed(42)
Ind=list(range(len(data)))
random.shuffle(Ind)
trainInd=Ind[:int(0.66*len(data))]
testInd=Ind[int(0.66*len(data)):]
OrigData=data.copy()
data=OrigData.iloc[trainInd]
test=OrigData.iloc[testInd]

filename = 'Indices.pkl'
if SaveSplits==False:
with open(filename, 'wb') as file:
    pickle.dump(trainInd, file)
    pickle.dump(testInd, file)
    pickle.dump(data, file)
    pickle.dump(test, file)


#Load the objects from the file
with open(filename, 'rb') as file:
    trainInd = pickle.load(file)
    testInd = pickle.load(file)
    data = pickle.load(file)
    test = pickle.load(file)



data['loan_status'] = data.loan_status.map({'Fully Paid':1, 'Charged Off':0})
OrigDFKeys=list(data.keys())
OrigDFKeys.append('zip_code')
pd.set_option('display.max_columns',100)
data
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='33bdbb50-57fc-48f6-a261-b2a5c41a05c8'>
#   <div id="cf4e29de-20ed-4138-bc5c-39fd7df798b1" data-root-id="33bdbb50-57fc-48f6-a261-b2a5c41a05c8" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6a6aca42-a26a-4e9e-a9ca-9b29c97b1856":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"33bdbb50-57fc-48f6-a261-b2a5c41a05c8"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"f3e532d9-60d0-448b-a677-f9013f4a8083","attributes":{"plot_id":"33bdbb50-57fc-48f6-a261-b2a5c41a05c8","comm_id":"fac7fa4c019e4d968cc542d59756ac5d","client_comm_id":"ecf8fe0b830c46a2bd5f2bb08224f8ef"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"6a6aca42-a26a-4e9e-a9ca-9b29c97b1856","roots":{"33bdbb50-57fc-48f6-a261-b2a5c41a05c8":"cf4e29de-20ed-4138-bc5c-39fd7df798b1"},"root_ids":["33bdbb50-57fc-48f6-a261-b2a5c41a05c8"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 232372    24000.0   36 months     15.99       843.66     D        D2
# 226851     7125.0   36 months     16.29       251.52     C        C4
# 35482      9500.0   36 months     14.33       326.22     C        C1
# 298295    20000.0   36 months     14.09       684.43     B        B5
# 162626    25450.0   60 months     23.28       721.55     F        F2
# ...           ...         ...       ...          ...   ...       ...
# 62899     15000.0   36 months     18.75       547.95     D        D3
# 243673     5200.0   36 months     13.35       176.09     C        C2
# 145956    15000.0   60 months     12.99       341.22     C        C2
# 66879      8000.0   36 months     10.99       261.88     B        B3
# 173741    10000.0   36 months     12.99       336.90     B        B4
#
#                           emp_title emp_length home_ownership  annual_inc  \
# 232372            Account Executive   < 1 year       MORTGAGE     95000.0
# 226851       BETHANY HOME CARE,INC.    5 years           RENT     28000.0
# 35482                  Novare Group    7 years       MORTGAGE     65000.0
# 298295          Dr.Marcus Black DDS   < 1 year            OWN     90000.0
# 162626         round top state bank     1 year       MORTGAGE     75000.0
# ...                             ...        ...            ...         ...
# 62899                       Borgata    9 years           RENT     60000.0
# 243673    Manager - Partner Success     1 year           RENT    110000.0
# 145956              General Manager    6 years       MORTGAGE     46000.0
# 66879   Respiratory therapist (CRT)  10+ years            OWN     42000.0
# 173741          Logistics Expeditor  10+ years       MORTGAGE     40000.0
#
#        verification_status   issue_d  loan_status             purpose  \
# 232372            Verified  Nov-2014            1    home_improvement
# 226851     Source Verified  Aug-2012            0               other
# 35482      Source Verified  Dec-2012            1         credit_card
# 298295        Not Verified  Sep-2012            1  debt_consolidation
# 162626            Verified  Dec-2012            1  debt_consolidation
# ...                    ...       ...          ...                 ...
# 62899             Verified  May-2013            0  debt_consolidation
# 243673            Verified  Jun-2014            1  debt_consolidation
# 145956     Source Verified  Dec-2014            1  debt_consolidation
# 66879             Verified  Jul-2014            1         credit_card
# 173741            Verified  Nov-2013            0  debt_consolidation
#
#                             title    dti earliest_cr_line  open_acc  pub_rec  \
# 232372           Home improvement  14.31         Oct-1994      16.0      0.0
# 226851              Personal loan  11.50         Nov-2006       8.0      0.0
# 35482   Credit Card Consolidation  14.82         Dec-1993      14.0      0.0
# 298295         Debt consolidation  24.75         Dec-1998      20.0      0.0
# 162626         Debt consolidation   8.13         Mar-1987      11.0      0.0
# ...                           ...    ...              ...       ...      ...
# 62899          Debt consolidation  28.06         Jan-1995      14.0      0.0
# 243673         Debt consolidation   8.38         Feb-1991       7.0      0.0
# 145956         Debt consolidation  21.39         May-2007       6.0      0.0
# 66879     Credit card refinancing  18.03         Aug-1996      15.0      0.0
# 173741                       Loan  28.83         Mar-1998       9.0      0.0
#
#         revol_bal  revol_util  total_acc initial_list_status application_type  \
# 232372    13468.0        64.1       41.0                   f       INDIVIDUAL
# 226851     4737.0        66.3       12.0                   f       INDIVIDUAL
# 35482     10835.0        62.3       33.0                   f       INDIVIDUAL
# 298295    19509.0        56.1       44.0                   f       INDIVIDUAL
# 162626     4528.0        22.8       25.0                   f       INDIVIDUAL
# ...           ...         ...        ...                 ...              ...
# 62899     11760.0        43.7       32.0                   f       INDIVIDUAL
# 243673     7865.0        72.2       37.0                   w       INDIVIDUAL
# 145956     9157.0        52.3        7.0                   w       INDIVIDUAL
# 66879      6431.0        45.3       23.0                   w       INDIVIDUAL
# 173741     9198.0        59.0       22.0                   w       INDIVIDUAL
#
#         mort_acc  pub_rec_bankruptcies  \
# 232372       2.0                   0.0
# 226851       0.0                   0.0
# 35482        1.0                   0.0
# 298295       2.0                   0.0
# 162626       0.0                   0.0
# ...          ...                   ...
# 62899        0.0                   0.0
# 243673       1.0                   0.0
# 145956       1.0                   0.0
# 66879        0.0                   0.0
# 173741       0.0                   0.0
#
#                                                   address
# 232372  682 Aimee Vista Apt. 857\r\nEast Paulfurt, AK ...
# 226851  585 Soto Row Apt. 014\r\nWest Williamberg, TN ...
# 35482         416 Robin Mountain\r\nMichaelside, WV 00813
# 298295                157 Jacob Loaf\r\nLeeland, WV 05113
# 162626  9980 Irwin Valleys Suite 322\r\nNew Monicaton,...
# ...                                                   ...
# 62899   707 Robert Heights Apt. 660\r\nEmilyfurt, CA 7...
# 243673    092 Jones Trafficway\r\nJudithborough, MT 48052
# 145956                         USNS Lopez\r\nFPO AP 05113
# 66879                  Unit 8922 Box 1072\r\nDPO AE 29597
# 173741  0935 Jennifer Bypass Suite 476\r\nAnthonybury,...
#
# [221672 rows x 27 columns]

# %% [markdown]
# ## Data Cleaning & Feature Engineering
#
# - **Feature Removal**: Eliminates redundant/low-value features:
#   - `emp_title` (too many unique job titles)
#   - `emp_length` (employment duration)
#   - `title` (duplicate of purpose)
# - **Categorical Handling**:
#   - Converts `term` from text to numeric (36/60 months)
#   - Creates dummy variables for categorical features
#   - Extracts zip code from address field for geospatial analysis
# - **Date Processing**:
#   - Converts `issue_d` and `earliest_cr_line` to year-based numeric features

# %%
# The length of the data
print(f"The Length of the data: {data.shape}")
# Out:
# The Length of the data: (221672, 96)

# %%
# Missing values
for column in data.columns:
    if data[column].isna().sum() != 0:
        missing = data[column].isna().sum()
        portion = (missing / data.shape[0]) * 100
        print(f"'{column}': number of missing values '{missing}' ==> '{portion:.3f}%'")

# %% [markdown]
# Drops employemnt emp_title, emp_length, and title due to lots of unique values

# %%
data.drop('emp_title', axis=1, inplace=True)

# %%
data.drop('emp_length', axis=1, inplace=True)

# %%
data.drop('title', axis=1, inplace=True)

# %% [markdown]
# Drops all rows with na values

# %%
data.dropna(inplace=True)

# %%
term_values = {' 36 months': 36, ' 60 months': 60}
data['term'] = data.term.map(term_values)

# %%
dummies = ['grade','sub_grade', 'verification_status', 'purpose', 'initial_list_status', 
           'application_type', 'home_ownership']
data = pd.get_dummies(data, columns=dummies, drop_first=False)

# %%
data['zip_code'] = data.address.apply(lambda x: x[-5:])
ZipToStateDF=data.copy()
ZipToStateDF['zip_code'] = ZipToStateDF.address.apply(lambda x: x[-5:])
ZipToStateDF['state'] = ZipToStateDF.address.apply(lambda x: x[-8:-5])

# %%
ZipToState={zipcode:state for (zipcode,state) in ZipToStateDF[['zip_code','state']].values}
ZipToState
# Out:
# {'70466': 'CA ',
#  '22690': 'HI ',
#  '00813': 'VT ',
#  '05113': 'AP ',
#  '29597': 'AE ',
#  '86630': 'ME ',
#  '11650': 'CA ',
#  '93700': 'UT ',
#  '30723': 'OK ',
#  '48052': 'MT '}

# %%
data.zip_code.value_counts()
# Out:
# zip_code
# 70466    31825
# 30723    31637
# 22690    31478
# 48052    31286
# 00813    25748
# 05113    25431
# 29597    25394
# 93700     6336
# 11650     6316
# 86630     6221
# Name: count, dtype: int64

# %%
data = pd.get_dummies(data, columns=['zip_code'], drop_first=False)

# %%
data.drop('address', axis=1, inplace=True)

# %%
data['issue_d'] = pd.to_datetime(data['issue_d'])
data['issue_d'] = data.issue_d.dt.year
# Out:
# /tmp/ipykernel_493/2345724880.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['issue_d'] = pd.to_datetime(data['issue_d'])

# %%
data['earliest_cr_line'] = pd.to_datetime(data['earliest_cr_line'])
data['earliest_cr_line'] = data.earliest_cr_line.dt.year
# Out:
# /tmp/ipykernel_493/1915473461.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['earliest_cr_line'] = pd.to_datetime(data['earliest_cr_line'])

# %% [markdown]
# # 🤖 Clustering & Seed Generation
# ## Cluster-based Distribution Analysis
#
# - **Clustering Strategy**:
#   - Uses KMeans (2 clusters) with standardized features
#   - Focuses on key financial metrics (loan amount, interest rate, income, etc.)
# - **Seed Instruction Creation**:
#   - Generates statistical profiles for each cluster
#   - Includes:
#     - Continuous variable distributions (mean, std, skew/kurtosis)
#     - Categorical distributions (proportions)
#     - Key business rules (grade, zip code, loan status)
#   - Applies sampling factor to control output size

# %%
#with grade
data2=data.copy()
del data2['home_ownership_OTHER']
del data2['home_ownership_OWN']
del data2['home_ownership_RENT']

del data2['application_type_INDIVIDUAL']
del data2['application_type_JOINT']

del data2['purpose_credit_card']
del data2['purpose_debt_consolidation']
del data2['purpose_educational']
del data2['purpose_home_improvement']
del data2['purpose_house']
del data2['purpose_major_purchase']
del data2['purpose_medical']
del data2['purpose_moving']
del data2['purpose_other']
del data2['purpose_renewable_energy']
del data2['purpose_small_business']
del data2['purpose_vacation']
del data2['purpose_wedding']



del data2['sub_grade_A1']
del data2['sub_grade_A2']
del data2['sub_grade_B1']
del data2['sub_grade_C1']
del data2['sub_grade_D1']
del data2['sub_grade_E1']
del data2['sub_grade_F1']
del data2['sub_grade_G1']
del data2['sub_grade_A3']
del data2['sub_grade_B2']
del data2['sub_grade_C2']
del data2['sub_grade_D2']
del data2['sub_grade_E2']
del data2['sub_grade_F2']
del data2['sub_grade_G2']
del data2['sub_grade_A4']
del data2['sub_grade_B3']
del data2['sub_grade_C3']
del data2['sub_grade_D3']
del data2['sub_grade_E3']
del data2['sub_grade_F3']
del data2['sub_grade_G3']
del data2['sub_grade_A5']
del data2['sub_grade_B4']
del data2['sub_grade_C4']
del data2['sub_grade_D4']
del data2['sub_grade_E4']
del data2['sub_grade_F4']
del data2['sub_grade_G4']
del data2['sub_grade_B5']
del data2['sub_grade_C5']
del data2['sub_grade_D5']
del data2['sub_grade_E5']
del data2['sub_grade_F5']
del data2['sub_grade_G5']

del data2['verification_status_Source Verified']
del data2['verification_status_Verified']

del data2['open_acc']
del data2['pub_rec']
del data2['revol_util']
del data2['total_acc']
del data2['initial_list_status_w']
del data2['installment']
del data2['revol_bal']

# %%
Keys=['grade_A',
 'grade_B',
 'grade_C',
 'grade_D',
 'grade_E',
 'grade_F',
 'grade_G',
 'zip_code_05113',
 'zip_code_11650',
 'zip_code_22690',
 'zip_code_29597',
 'zip_code_30723',
 'zip_code_48052',
 'zip_code_70466',
 'zip_code_86630',
 'zip_code_93700',
 'loan_status']

# %%
from sklearn.cluster import KMeans,DBSCAN
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scalerAll=StandardScaler()
#X_ScaledAll=scaler.fit_transform(data)

ClusteringKeys=[
   'loan_amnt',
    'term',
    'int_rate',
    'annual_inc',
    'dti',
    'earliest_cr_line',
    'mort_acc',
    'pub_rec_bankruptcies'
]

# %%
ContinuousVariables=[
  'loan_amnt', 
  'int_rate',
  'installment',
  'annual_inc',
  'issue_d',
  'dti',
  'earliest_cr_line',
  'open_acc', 
  'pub_rec',
  'revol_bal',
  'revol_util',
  'total_acc',
  'mort_acc',
  'pub_rec_bankruptcies'
]

PrimaryDiscreteVariables=[
  'grade',
  'zip_code',
]
PrimaryBinaryDiscreteVariables=[
  'loan_status'
]

PrimaryBinaryDiscreteDistributionVariables=[
  'term'
]

      
SecondaryDistributionVariables=[
  'sub_grade',
  'verification_status',
  'purpose',
  'initial_list_status',       
  'application_type',
  'home_ownership',
]

DummyVariables={
  'grade': ['A', 'B', 'C', 'D','E', 'F', 'G'],
  'sub_grade':['1', '2', '3', '4', '5'],
  'verification_status': ['Not Verified', 'Source Verified', 'Verified'],
  'purpose':['car', 'credit_card', 'debt_consolidation', 'educational', 'home_improvement', 'house', 'major_purchase', 'medical', 'moving', 'other','renewable_energy','small_business','vacation', 'wedding'], 
  'initial_list_status': ['f', 'w']  ,       
  'application_type': ['DIRECT_PAY', 'INDIVIDUAL', 'JOINT'],
  'home_ownership': ['RENT','MORTGAGE', 'OWN','ANY', 'NONE', 'OTHER'],
  'zip_code':['00813', '05113', '11650', '22690','29597', '30723', '48052', '70466', '86630', '93700'],
  'loan_status':['Charged Off', 'Paid Fully'],
  'term':[36, 60]
}

# %% [markdown]
# ## 🧠 Key Design Decisions
# 1. **Feature Selection**: Focuses on 8 core clustering variables that best represent loan risk profiles
# 2. **Cluster Replication**: Uses sampling factor to balance representativeness and output size
# 3. **Statistical Depth**: Captures both central tendencies and distribution shape (skew/kurtosis)
# 4. **Business Context**: Preserves key categorical relationships (grade-sub_grade, zip_code-state)

# %%
GroupsIter=iter(data.groupby(Keys))
print(len(data))
import numpy as np
lens=[]
lens_cluster=[]
FinalSeeds=[]
CurrentSeed=[]
NumOfClusters=2
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
SamplingFactor=100
AllDFLen=[]
for name,df2 in GroupsIter:
    X_Scaled=scaler.fit_transform(df2[ClusteringKeys])
    X_ScaledAll=scaler.fit_transform(df2)

    kmeans=KMeans(n_clusters=NumOfClusters,n_init='auto',random_state=42)
    kmeans.fit(X_ScaledAll)
    
    labels=kmeans.labels_

    for ClusterInd in range(0,NumOfClusters):
        CurrentSeed=[]

        Ind=np.where(kmeans.labels_==ClusterInd)[0]
        ClusterRep=len(Ind)
        df=df2.iloc[Ind]
        CurrGrade='A'
        for key in OrigDFKeys:
            if key in ContinuousVariables:
                m=round(df[key].mean(numeric_only=True),2)
                s=round(df[key].std(numeric_only=True),2)
                kur=round(df[key].kurtosis(numeric_only=True),2)
                skewn=round(df[key].skew(numeric_only=True),2)
                mystr=f'{key}: mean={m}, std={s}, kurtosis={kur}, skewness={skewn}'
                #print(mystr)
            elif key in PrimaryDiscreteVariables:
                for SubKey in DummyVariables[key]:
                  if df[key+'_'+SubKey].all():
                      mystr=key+'='+SubKey
                      if key=='grade':
                        CurrGrade=SubKey
                      if key=='zip_code':
                        mystr='address: ' + 'State zipcode'+'='+ZipToState[SubKey]+SubKey


            elif key in PrimaryBinaryDiscreteVariables:
                if df[key].all() and key=="loan_status":
                    mystr=key+'=Fully Paid'
                elif key=="loan_status":
                    mystr=key+'=Charged Off'

                #print(mystr)
            elif key in SecondaryDistributionVariables:
                SecondaryValues=[]
                SecondaryKeys=[]
                for Skey in DummyVariables[key]:
                  if key!='sub_grade':
                    SecondaryValues.append(df[key+'_'+Skey].sum())
                    SecondaryKeys.append(Skey)
                  else:
                    SecondaryValues.append(df[key+'_'+CurrGrade+Skey].sum())
                    SecondaryKeys.append(CurrGrade+Skey)

                      
                mystr=key + ": "+", ".join([k+'='+str(round(val/np.sum(SecondaryValues),2))  for val,k in zip(SecondaryValues,SecondaryKeys)])
            elif key in PrimaryBinaryDiscreteDistributionVariables:
                SecondaryValues=[]
                SecondaryKeys=[]

                for Skey in DummyVariables[key]:
                    SecondaryValues.append(np.sum(df[key]==Skey))
                    SecondaryKeys.append(Skey)
                if key=="term":
                  mystr=key + ": "+", ".join([str(k)+ " months"+'='+str(round(val/np.sum(SecondaryValues),2))  for val,k in zip(SecondaryValues,SecondaryKeys)])
                else:
                  mystr=key + ": "+", ".join([str(k)+'='+str(round(val/np.sum(SecondaryValues),2))  for val,k in zip(SecondaryValues,SecondaryKeys)])
                #print(s)
            else:
                continue

            CurrentSeed.append(mystr)
        
        AllDFLen.append(ClusterRep)
        for RepCount in range(0,int(ClusterRep/SamplingFactor)):
            FinalSeeds.append(CurrentSeed)

    lens.append(len(df))
# Out:
# 221672

# %%
random.shuffle(FinalSeeds)
FinalSeeds[0:5]
# Out:
# [['loan_amnt: mean=18272.17, std=7814.85, kurtosis=-0.45, skewness=0.38',
#   'term: 36 months=0.81, 60 months=0.19',
#   'int_rate: mean=11.09, std=1.45, kurtosis=-0.66, skewness=-0.08',
#   'installment: mean=557.01, std=250.39, kurtosis=-0.16, skewness=0.61',
#   'grade=B',
#   'sub_grade: B1=0.18, B2=0.21, B3=0.22, B4=0.22, B5=0.16',
#   'home_ownership: RENT=0.11, MORTGAGE=0.83, OWN=0.06, ANY=0.0, NONE=0.0, OTHER=0.0',
#   'annual_inc: mean=100035.54, std=57485.2, kurtosis=33.28, skewness=4.04',
#   'verification_status: Not Verified=0.24, Source Verified=0.36, Verified=0.41',
#   'issue_d: mean=2013.9, std=1.1, kurtosis=-0.84, skewness=0.17',
#   'loan_status=Fully Paid',
#   'purpose: car=0.0, credit_card=0.28, debt_consolidation=0.6, educational=0.0, home_improvement=0.08, house=0.0, major_purchase=0.01, medical=0.0, moving=0.0, other=0.01, renewable_energy=0.0, small_business=0.01, vacation=0.0, wedding=0.0',
#   'dti: mean=17.48, std=7.64, kurtosis=-0.48, skewness=0.24',
#   'earliest_cr_line: mean=1995.05, std=7.02, kurtosis=1.4, skewness=-1.02',
#   'open_acc: mean=13.59, std=5.55, kurtosis=4.31, skewness=1.38',
#   'pub_rec: mean=0.12, std=0.4, kurtosis=31.38, skewness=4.69',
#   'revol_bal: mean=24045.8, std=26134.43, kurtosis=56.93, skewness=5.83',
#   'revol_util: mean=54.69, std=22.75, kurtosis=-0.7, skewness=-0.17',
#   'total_acc: mean=32.18, std=11.58, kurtosis=0.9, skewness=0.78',
#   'initial_list_status: f=0.51, w=0.49',
#   'application_type: DIRECT_PAY=0.0, INDIVIDUAL=1.0, JOINT=0.0',
#   'mort_acc: mean=3.22, std=2.33, kurtosis=2.61, skewness=1.08',
#   'pub_rec_bankruptcies: mean=0.07, std=0.25, kurtosis=12.78, skewness=3.7',
#   'address: State zipcode=CA 70466'],
#  ['loan_amnt: mean=9617.89, std=4585.71, kurtosis=0.37, skewness=0.67',
#   'term: 36 months=0.97, 60 months=0.03',
#   'int_rate: mean=11.35, std=1.46, kurtosis=-0.63, skewness=-0.14',
#   'installment: mean=312.75, std=148.65, kurtosis=0.51, skewness=0.7',
#   'grade=B',
#   'sub_grade: B1=0.15, B2=0.2, B3=0.24, B4=0.23, B5=0.19',
#   'home_ownership: RENT=0.58, MORTGAGE=0.32, OWN=0.1, ANY=0.0, NONE=0.0, OTHER=0.0',
#   'annual_inc: mean=58650.64, std=25369.43, kurtosis=4.45, skewness=1.47',
#   'verification_status: Not Verified=0.53, Source Verified=0.28, Verified=0.19',
#   'issue_d: mean=2013.69, std=1.15, kurtosis=-0.81, skewness=0.29',
#   'loan_status=Fully Paid',
#   'purpose: car=0.02, credit_card=0.26, debt_consolidation=0.58, educational=0.0, home_improvement=0.05, house=0.0, major_purchase=0.02, medical=0.01, moving=0.0, other=0.04, renewable_energy=0.0, small_business=0.0, vacation=0.01, wedding=0.0',
#   'dti: mean=16.24, std=7.62, kurtosis=-0.49, skewness=0.28',
#   'earliest_cr_line: mean=1999.77, std=6.23, kurtosis=2.06, skewness=-1.13',
#   'open_acc: mean=9.98, std=4.02, kurtosis=1.33, skewness=0.95',
#   'pub_rec: mean=0.22, std=0.57, kurtosis=114.12, skewness=6.97',
#   'revol_bal: mean=10229.17, std=7227.25, kurtosis=11.41, skewness=2.09',
#   'revol_util: mean=51.34, std=22.57, kurtosis=-0.69, skewness=-0.06',
#   'total_acc: mean=21.55, std=9.35, kurtosis=1.07, skewness=0.85',
#   'initial_list_status: f=0.63, w=0.37',
#   'application_type: DIRECT_PAY=0.0, INDIVIDUAL=1.0, JOINT=0.0',
#   'mort_acc: mean=0.93, std=1.41, kurtosis=3.67, skewness=1.82',
#   'pub_rec_bankruptcies: mean=0.16, std=0.4, kurtosis=7.51, skewness=2.54',
#   'address: State zipcode=CA 70466'],
#  ['loan_amnt: mean=20076.44, std=8734.77, kurtosis=-0.9, skewness=0.17',
#   'term: 36 months=0.58, 60 months=0.42',
#   'int_rate: mean=14.4, std=1.29, kurtosis=-0.55, skewness=0.19',
#   'installment: mean=593.14, std=283.86, kurtosis=-0.37, skewness=0.62',
#   'grade=C',
#   'sub_grade: C1=0.21, C2=0.2, C3=0.2, C4=0.19, C5=0.2',
#   'home_ownership: RENT=0.13, MORTGAGE=0.79, OWN=0.07, ANY=0.0, NONE=0.0, OTHER=0.0',
#   'annual_inc: mean=96301.15, std=54116.03, kurtosis=43.46, skewness=4.35',
#   'verification_status: Not Verified=0.15, Source Verified=0.37, Verified=0.48',
#   'issue_d: mean=2014.08, std=1.08, kurtosis=-0.81, skewness=0.02',
#   'loan_status=Fully Paid',
#   'purpose: car=0.0, credit_card=0.2, debt_consolidation=0.67, educational=0.0, home_improvement=0.08, house=0.0, major_purchase=0.01, medical=0.01, moving=0.0, other=0.02, renewable_energy=0.0, small_business=0.01, vacation=0.0, wedding=0.0',
#   'dti: mean=18.36, std=7.8, kurtosis=-0.45, skewness=0.2',
#   'earliest_cr_line: mean=1995.72, std=6.96, kurtosis=1.36, skewness=-1.02',
#   'open_acc: mean=13.41, std=5.49, kurtosis=2.36, skewness=1.12',
#   'pub_rec: mean=0.17, std=0.5, kurtosis=42.71, skewness=5.06',
#   'revol_bal: mean=23906.53, std=24671.33, kurtosis=36.37, skewness=4.79',
#   'revol_util: mean=58.25, std=22.43, kurtosis=-0.51, skewness=-0.31',
#   'total_acc: mean=31.73, std=11.73, kurtosis=1.09, skewness=0.81',
#   'initial_list_status: f=0.5, w=0.5',
#   'application_type: DIRECT_PAY=0.0, INDIVIDUAL=1.0, JOINT=0.0',
#   'mort_acc: mean=3.03, std=2.29, kurtosis=5.05, skewness=1.27',
#   'pub_rec_bankruptcies: mean=0.11, std=0.34, kurtosis=13.43, skewness=3.3',
#   'address: State zipcode=MT 48052'],
#  ['loan_amnt: mean=9597.39, std=4593.99, kurtosis=0.33, skewness=0.66',
#   'term: 36 months=0.98, 60 months=0.02',
#   'int_rate: mean=11.37, std=1.43, kurtosis=-0.64, skewness=-0.15',
#   'installment: mean=312.79, std=149.93, kurtosis=0.44, skewness=0.7',
#   'grade=B',
#   'sub_grade: B1=0.16, B2=0.18, B3=0.24, B4=0.22, B5=0.2',
#   'home_ownership: RENT=0.56, MORTGAGE=0.33, OWN=0.11, ANY=0.0, NONE=0.0, OTHER=0.0',
#   'annual_inc: mean=58774.79, std=25233.69, kurtosis=4.13, skewness=1.45',
#   'verification_status: Not Verified=0.55, Source Verified=0.26, Verified=0.2',
#   'issue_d: mean=2013.66, std=1.12, kurtosis=-0.73, skewness=0.3',
#   'loan_status=Fully Paid',
#   'purpose: car=0.01, credit_card=0.29, debt_consolidation=0.56, educational=0.0, home_improvement=0.04, house=0.0, major_purchase=0.02, medical=0.01, moving=0.0, other=0.04, renewable_energy=0.0, small_business=0.0, vacation=0.01, wedding=0.0',
#   'dti: mean=16.27, std=7.72, kurtosis=-0.55, skewness=0.28',
#   'earliest_cr_line: mean=1999.79, std=6.18, kurtosis=1.96, skewness=-1.09',
#   'open_acc: mean=10.0, std=4.09, kurtosis=1.11, skewness=0.92',
#   'pub_rec: mean=0.21, std=0.55, kurtosis=42.98, skewness=4.83',
#   'revol_bal: mean=10725.16, std=7952.79, kurtosis=11.85, skewness=2.24',
#   'revol_util: mean=52.37, std=22.43, kurtosis=-0.67, skewness=-0.11',
#   'total_acc: mean=21.34, std=9.38, kurtosis=0.64, skewness=0.77',
#   'initial_list_status: f=0.67, w=0.33',
#   'application_type: DIRECT_PAY=0.0, INDIVIDUAL=1.0, JOINT=0.0',
#   'mort_acc: mean=0.95, std=1.39, kurtosis=2.8, skewness=1.7',
#   'pub_rec_bankruptcies: mean=0.16, std=0.39, kurtosis=10.69, skewness=2.75',
#   'address: State zipcode=MT 48052'],
#  ['loan_amnt: mean=13205.71, std=7416.47, kurtosis=0.59, skewness=0.93',
#   'term: 36 months=0.91, 60 months=0.09',
#   'int_rate: mean=11.27, std=1.43, kurtosis=-0.56, skewness=-0.14',
#   'installment: mean=414.78, std=228.73, kurtosis=1.12, skewness=1.05',
#   'grade=B',
#   'sub_grade: B1=0.16, B2=0.2, B3=0.23, B4=0.22, B5=0.18',
#   'home_ownership: RENT=0.43, MORTGAGE=0.57, OWN=0.0, ANY=0.0, NONE=0.0, OTHER=0.0',
#   'annual_inc: mean=74791.77, std=48132.73, kurtosis=355.82, skewness=11.18',
#   'verification_status: Not Verified=0.4, Source Verified=0.32, Verified=0.28',
#   'issue_d: mean=2013.74, std=1.12, kurtosis=-0.78, skewness=0.24',
#   'loan_status=Fully Paid',
#   'purpose: car=0.01, credit_card=0.29, debt_consolidation=0.63, educational=0.0, home_improvement=0.0, house=0.0, major_purchase=0.02, medical=0.01, moving=0.0, other=0.03, renewable_energy=0.0, small_business=0.0, vacation=0.0, wedding=0.0',
#   'dti: mean=16.82, std=7.52, kurtosis=-0.49, skewness=0.25',
#   'earliest_cr_line: mean=1997.86, std=6.93, kurtosis=1.12, skewness=-0.98',
#   'open_acc: mean=11.34, std=4.9, kurtosis=2.79, skewness=1.18',
#   'pub_rec: mean=0.17, std=0.49, kurtosis=38.7, skewness=4.84',
#   'revol_bal: mean=16046.73, std=17112.29, kurtosis=75.78, skewness=6.09',
#   'revol_util: mean=54.38, std=22.65, kurtosis=-0.66, skewness=-0.17',
#   'total_acc: mean=25.51, std=11.35, kurtosis=1.26, skewness=0.89',
#   'initial_list_status: f=0.6, w=0.4',
#   'application_type: DIRECT_PAY=0.0, INDIVIDUAL=1.0, JOINT=0.0',
#   'mort_acc: mean=1.87, std=2.13, kurtosis=3.73, skewness=1.46',
#   'pub_rec_bankruptcies: mean=0.12, std=0.36, kurtosis=37.07, skewness=4.3',
#   'address: State zipcode=HI 22690']]

# %% [markdown]
# ## 📤 Output Generation
#
# - Exports seed instructions to JSON file
# - Format contains 100+ statistical descriptors per cluster
# - Ready for use with Synthetic Data Generation (SDS) systems

# %%
import json
file_path = "SeedsInstructions.json"

with open(file_path, 'w') as json_file:
    json.dump(FinalSeeds, json_file, indent=4)
